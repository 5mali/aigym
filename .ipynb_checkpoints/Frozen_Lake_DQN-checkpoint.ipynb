# %%
import gym
import numpy as np
import tensorflow as tf

# %%
env = gym.make('FrozenLake-v0')

# %%
#The grid with 4x4 gives 16 possible states, hence we have an array of 16 states.
inputs = tf.placeholder(shape=[1,16],dtype=tf.float32)
#Each state has 4 possible outcomes, hence we have 16x4 matrix with weights uniformly distributed
weights = tf.Variable(tf.random_uniform([16,4],0,0.1))
#Find the dot product of inputs and the weights
Q1 = tf.matmul(inputs,weights)
#The next state will be the opted based on the argmax function.
output = tf.argmax(Q1,1)

# %%
# We will use Gradient optimizer to reduce the loss with a learning rate of 0.1

Q2 = tf.placeholder(shape=[1,4],dtype=tf.float32)
loss = tf.reduce_sum(tf.square(Q2 - Q1))
gdo = tf.train.GradientDescentOptimizer(learning_rate=0.1)
updatedweights = gdo.minimize(loss)

# %%
gamma = 0.9
epsilon = 0.1
episodes = 2000

totalReward = 0

session = tf.Session()
session.run(tf.initialize_all_variables())
for i in range(episodes):
    state_now = env.reset()
    done = False
    reward = 0
    for j in range(100):
        #Lets find the dot product of the inputs with the weights and apply argmax on it.
        action , Y = session.run([output, Q1], feed_dict = {inputs : [np.eye(16)[state_now]]})
        if epsilon > np.random.rand(1):
            action[0] = env.action_space.sample()
            epsilon -= 10**-3
        #Lets iterate to the next state Note: This can be random.
        state_next , reward, done, _ = env.step(action[0])
        Y1 = session.run(Q1, feed_dict = {inputs : [np.eye(16)[state_next]]})
        change_Y = Y
        change_Y[0, action[0]] = reward + gamma*np.max(Y1)
        #Updating the weights 
        _,new_weights = session.run([updatedweights,weights],feed_dict={inputs:[np.eye(16)[state_now]],Q2:change_Y})
        #Lets append the total number of rewards
        totalReward += reward
        state_now = state_next
        if reward == 1:
            print ('Episode {} was successful, Agent reached the Goal'.format(i))
            
session.close()
# Out:
# WARNING:tensorflow:From /home/bhootmali/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Episode 3 was successful, Agent reached the Goal
# Episode 32 was successful, Agent reached the Goal
# Episode 41 was successful, Agent reached the Goal
# Episode 62 was successful, Agent reached the Goal
# Episode 75 was successful, Agent reached the Goal
# Episode 78 was successful, Agent reached the Goal
# Episode 80 was successful, Agent reached the Goal
# Episode 81 was successful, Agent reached the Goal
# Episode 84 was successful, Agent reached the Goal
# Episode 96 was successful, Agent reached the Goal
# Episode 97 was successful, Agent reached the Goal
# Episode 100 was successful, Agent reached the Goal
# Episode 101 was successful, Agent reached the Goal
# Episode 107 was successful, Agent reached the Goal
# Episode 113 was successful, Agent reached the Goal
# Episode 114 was successful, Agent reached the Goal
# Episode 117 was successful, Agent reached the Goal
# Episode 119 was successful, Agent reached the Goal
# Episode 120 was successful, Agent reached the Goal
# Episode 123 was successful, Agent reached the Goal
# Episode 124 was successful, Agent reached the Goal
# Episode 127 was successful, Agent reached the Goal
# Episode 132 was successful, Agent reached the Goal
# Episode 138 was successful, Agent reached the Goal
# Episode 144 was successful, Agent reached the Goal
# Episode 174 was successful, Agent reached the Goal
# Episode 184 was successful, Agent reached the Goal
# Episode 192 was successful, Agent reached the Goal
# Episode 193 was successful, Agent reached the Goal
# Episode 194 was successful, Agent reached the Goal
# Episode 202 was successful, Agent reached the Goal
# Episode 203 was successful, Agent reached the Goal
# Episode 212 was successful, Agent reached the Goal
# Episode 217 was successful, Agent reached the Goal
# Episode 219 was successful, Agent reached the Goal
# Episode 226 was successful, Agent reached the Goal
# Episode 230 was successful, Agent reached the Goal
# Episode 234 was successful, Agent reached the Goal
# Episode 235 was successful, Agent reached the Goal
# Episode 251 was successful, Agent reached the Goal
# Episode 255 was successful, Agent reached the Goal
# Episode 265 was successful, Agent reached the Goal
# Episode 266 was successful, Agent reached the Goal
# Episode 267 was successful, Agent reached the Goal
# Episode 282 was successful, Agent reached the Goal
# Episode 283 was successful, Agent reached the Goal
# Episode 288 was successful, Agent reached the Goal
# Episode 294 was successful, Agent reached the Goal
# Episode 297 was successful, Agent reached the Goal
# Episode 298 was successful, Agent reached the Goal
# Episode 299 was successful, Agent reached the Goal
# Episode 304 was successful, Agent reached the Goal
# Episode 312 was successful, Agent reached the Goal
# Episode 321 was successful, Agent reached the Goal
# Episode 327 was successful, Agent reached the Goal
# Episode 330 was successful, Agent reached the Goal
# Episode 335 was successful, Agent reached the Goal
# Episode 338 was successful, Agent reached the Goal
# Episode 339 was successful, Agent reached the Goal
# Episode 349 was successful, Agent reached the Goal
# Episode 358 was successful, Agent reached the Goal
# Episode 360 was successful, Agent reached the Goal
# Episode 361 was successful, Agent reached the Goal
# Episode 366 was successful, Agent reached the Goal
# Episode 369 was successful, Agent reached the Goal
# Episode 374 was successful, Agent reached the Goal
# Episode 375 was successful, Agent reached the Goal
# Episode 378 was successful, Agent reached the Goal
# Episode 379 was successful, Agent reached the Goal
# Episode 386 was successful, Agent reached the Goal
# Episode 392 was successful, Agent reached the Goal
# Episode 393 was successful, Agent reached the Goal
# Episode 401 was successful, Agent reached the Goal
# Episode 406 was successful, Agent reached the Goal
# Episode 408 was successful, Agent reached the Goal
# Episode 417 was successful, Agent reached the Goal
# Episode 418 was successful, Agent reached the Goal
# Episode 422 was successful, Agent reached the Goal
# Episode 425 was successful, Agent reached the Goal
# Episode 428 was successful, Agent reached the Goal
# Episode 430 was successful, Agent reached the Goal
# Episode 434 was successful, Agent reached the Goal
# Episode 441 was successful, Agent reached the Goal
# Episode 443 was successful, Agent reached the Goal
# Episode 445 was successful, Agent reached the Goal
# Episode 450 was successful, Agent reached the Goal
# Episode 466 was successful, Agent reached the Goal
# Episode 480 was successful, Agent reached the Goal
# Episode 486 was successful, Agent reached the Goal
# Episode 488 was successful, Agent reached the Goal
# Episode 489 was successful, Agent reached the Goal
# Episode 490 was successful, Agent reached the Goal
# Episode 497 was successful, Agent reached the Goal
# Episode 507 was successful, Agent reached the Goal
# Episode 509 was successful, Agent reached the Goal
# Episode 510 was successful, Agent reached the Goal
# Episode 515 was successful, Agent reached the Goal
# Episode 520 was successful, Agent reached the Goal
# Episode 526 was successful, Agent reached the Goal
# Episode 527 was successful, Agent reached the Goal
# Episode 533 was successful, Agent reached the Goal
# Episode 534 was successful, Agent reached the Goal
# Episode 536 was successful, Agent reached the Goal
# Episode 564 was successful, Agent reached the Goal
# Episode 567 was successful, Agent reached the Goal
# Episode 584 was successful, Agent reached the Goal
# Episode 585 was successful, Agent reached the Goal
# Episode 586 was successful, Agent reached the Goal
# Episode 587 was successful, Agent reached the Goal
# Episode 588 was successful, Agent reached the Goal
# Episode 589 was successful, Agent reached the Goal
# Episode 596 was successful, Agent reached the Goal
# Episode 598 was successful, Agent reached the Goal
# Episode 603 was successful, Agent reached the Goal
# Episode 605 was successful, Agent reached the Goal
# Episode 609 was successful, Agent reached the Goal
# Episode 620 was successful, Agent reached the Goal
# Episode 623 was successful, Agent reached the Goal
# Episode 633 was successful, Agent reached the Goal
# Episode 638 was successful, Agent reached the Goal
# Episode 644 was successful, Agent reached the Goal
# Episode 647 was successful, Agent reached the Goal
# Episode 671 was successful, Agent reached the Goal
# Episode 673 was successful, Agent reached the Goal
# Episode 674 was successful, Agent reached the Goal
# Episode 678 was successful, Agent reached the Goal
# Episode 680 was successful, Agent reached the Goal
# Episode 684 was successful, Agent reached the Goal
# Episode 685 was successful, Agent reached the Goal
# Episode 688 was successful, Agent reached the Goal
# Episode 690 was successful, Agent reached the Goal
# Episode 702 was successful, Agent reached the Goal
# Episode 712 was successful, Agent reached the Goal
# Episode 714 was successful, Agent reached the Goal
# Episode 720 was successful, Agent reached the Goal
# Episode 731 was successful, Agent reached the Goal
# Episode 735 was successful, Agent reached the Goal
# Episode 739 was successful, Agent reached the Goal
# Episode 741 was successful, Agent reached the Goal
# Episode 751 was successful, Agent reached the Goal
# Episode 753 was successful, Agent reached the Goal
# Episode 760 was successful, Agent reached the Goal
# Episode 767 was successful, Agent reached the Goal
# Episode 768 was successful, Agent reached the Goal
# Episode 770 was successful, Agent reached the Goal
# Episode 774 was successful, Agent reached the Goal
# Episode 778 was successful, Agent reached the Goal
# Episode 780 was successful, Agent reached the Goal
# Episode 783 was successful, Agent reached the Goal
# Episode 801 was successful, Agent reached the Goal
# Episode 805 was successful, Agent reached the Goal
# Episode 806 was successful, Agent reached the Goal
# Episode 809 was successful, Agent reached the Goal
# Episode 812 was successful, Agent reached the Goal
# Episode 814 was successful, Agent reached the Goal
# Episode 816 was successful, Agent reached the Goal
# Episode 820 was successful, Agent reached the Goal
# Episode 821 was successful, Agent reached the Goal
# Episode 823 was successful, Agent reached the Goal
# Episode 828 was successful, Agent reached the Goal
# Episode 834 was successful, Agent reached the Goal
# Episode 845 was successful, Agent reached the Goal
# Episode 849 was successful, Agent reached the Goal
# Episode 850 was successful, Agent reached the Goal
# Episode 855 was successful, Agent reached the Goal
# Episode 860 was successful, Agent reached the Goal
# Episode 863 was successful, Agent reached the Goal
# Episode 866 was successful, Agent reached the Goal
# Episode 884 was successful, Agent reached the Goal
# Episode 888 was successful, Agent reached the Goal
# Episode 890 was successful, Agent reached the Goal
# Episode 894 was successful, Agent reached the Goal
# Episode 909 was successful, Agent reached the Goal
# Episode 911 was successful, Agent reached the Goal
# Episode 912 was successful, Agent reached the Goal
# Episode 919 was successful, Agent reached the Goal
# Episode 924 was successful, Agent reached the Goal
# Episode 925 was successful, Agent reached the Goal
# Episode 933 was successful, Agent reached the Goal
# Episode 937 was successful, Agent reached the Goal
# Episode 938 was successful, Agent reached the Goal
# Episode 940 was successful, Agent reached the Goal
# Episode 943 was successful, Agent reached the Goal
# Episode 947 was successful, Agent reached the Goal
# Episode 953 was successful, Agent reached the Goal
# Episode 957 was successful, Agent reached the Goal
# Episode 961 was successful, Agent reached the Goal
# Episode 962 was successful, Agent reached the Goal
# Episode 964 was successful, Agent reached the Goal
# Episode 972 was successful, Agent reached the Goal
# Episode 977 was successful, Agent reached the Goal
# Episode 979 was successful, Agent reached the Goal
# Episode 982 was successful, Agent reached the Goal
# Episode 983 was successful, Agent reached the Goal
# Episode 990 was successful, Agent reached the Goal
# Episode 994 was successful, Agent reached the Goal
# Episode 996 was successful, Agent reached the Goal
# Episode 1000 was successful, Agent reached the Goal
# Episode 1001 was successful, Agent reached the Goal
# Episode 1004 was successful, Agent reached the Goal
# Episode 1007 was successful, Agent reached the Goal
# Episode 1017 was successful, Agent reached the Goal
# Episode 1020 was successful, Agent reached the Goal
# Episode 1024 was successful, Agent reached the Goal
# Episode 1028 was successful, Agent reached the Goal
# Episode 1029 was successful, Agent reached the Goal
# Episode 1031 was successful, Agent reached the Goal
# Episode 1032 was successful, Agent reached the Goal
# Episode 1034 was successful, Agent reached the Goal
# Episode 1039 was successful, Agent reached the Goal
# Episode 1045 was successful, Agent reached the Goal
# Episode 1051 was successful, Agent reached the Goal
# Episode 1053 was successful, Agent reached the Goal
# Episode 1055 was successful, Agent reached the Goal
# Episode 1058 was successful, Agent reached the Goal
# Episode 1060 was successful, Agent reached the Goal
# Episode 1067 was successful, Agent reached the Goal
# Episode 1080 was successful, Agent reached the Goal
# Episode 1083 was successful, Agent reached the Goal
# Episode 1089 was successful, Agent reached the Goal
# Episode 1093 was successful, Agent reached the Goal
# Episode 1094 was successful, Agent reached the Goal
# Episode 1096 was successful, Agent reached the Goal
# Episode 1101 was successful, Agent reached the Goal
# Episode 1105 was successful, Agent reached the Goal
# Episode 1109 was successful, Agent reached the Goal
# Episode 1110 was successful, Agent reached the Goal
# Episode 1112 was successful, Agent reached the Goal
# Episode 1113 was successful, Agent reached the Goal
# Episode 1114 was successful, Agent reached the Goal
# Episode 1123 was successful, Agent reached the Goal
# Episode 1127 was successful, Agent reached the Goal
# Episode 1145 was successful, Agent reached the Goal
# Episode 1147 was successful, Agent reached the Goal
# Episode 1152 was successful, Agent reached the Goal
# Episode 1158 was successful, Agent reached the Goal
# Episode 1159 was successful, Agent reached the Goal
# Episode 1160 was successful, Agent reached the Goal
# Episode 1165 was successful, Agent reached the Goal
# Episode 1167 was successful, Agent reached the Goal
# Episode 1171 was successful, Agent reached the Goal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-13dd3d0b60ec> in <module>
#      19         #Lets iterate to the next state Note: This can be random.
#      20         state_next , reward, done, _ = env.step(action[0])
# ---> 21         Y1 = session.run(Q1, feed_dict = {inputs : [np.eye(16)[state_next]]})
#      22         change_Y = Y
#      23         change_Y[0, action[0]] = reward + gamma*np.max(Y1)
#
# ~/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# ~/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1290   def _do_call(self, fn, *args):
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#    1294       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1275       self._extend_graph()
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#    1279     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/eno/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1365     return tf_session.TF_SessionRun_wrapper(
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#    1369   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
