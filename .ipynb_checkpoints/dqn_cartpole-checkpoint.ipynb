# %%
# """
# View more, visit my tutorial page: https://morvanzhou.github.io/tutorials/
# My Youtube Channel: https://www.youtube.com/user/MorvanZhou
# More about Reinforcement learning: https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/
# Dependencies:
# torch: 0.4
# gym: 0.8.1
# numpy
# """

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
# random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# Hyper Parameters
BATCH_SIZE = 32
LR = 1e-2                  # learning rate
EPSILON = 0.9               # greedy policy
GAMMA = 0.9                 # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY = 2000

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped

# %%
N_ACTIONS = env.action_space.n
N_STATES = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        self.fc1.weight.data.normal_(0, 0.1)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        self.out.weight.data.normal_(0, 0.1)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter = 0                                     # for target updating
        self.memory_counter = 0                                         # for storing memory
        self.memory = np.zeros((MEMORY_CAPACITY, N_STATES * 2 + 2))     # initialize memory
        self.optimizer = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func = nn.MSELoss()

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        # replace the old memory with new memory
        index = self.memory_counter % MEMORY_CAPACITY
        self.memory[index, :] = transition
        self.memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # sample batch transitions
        sample_index = np.random.choice(MEMORY_CAPACITY, BATCH_SIZE)
        b_memory = self.memory[sample_index, :]
        b_s = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a = torch.LongTensor(b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

        # q_eval w.r.t the action in experience
        q_eval = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        q_next = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.max(1)[0].view(BATCH_SIZE, 1)   # shape (batch, 1)
        loss = self.loss_func(q_eval, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = 1000

# %%
print('\nCollecting experience...')
ep_r_rec = []
time_rec = []
for i_episode in range(NO_OF_EPISODES):

    s = env.reset()
    ep_r = 0
    time_steps = 0
    while True:
#         env.render()
        time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)

        # modify the reward
        x, x_dot, theta, theta_dot = s_
        r1 = (env.x_threshold - abs(x)) / env.x_threshold - 0.8
        r2 = (env.theta_threshold_radians - abs(theta)) / env.theta_threshold_radians - 0.5
        r = r1 + r2

        dqn.store_transition(s, a, r, s_)
        ep_r += r
        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()
            
        if done:
            ep_r_rec = np.append(ep_r_rec, ep_r)
            time_rec = np.append(time_rec, time_steps)
            if time_steps > 2000:
                print('EPISODE: {:4d}  |  REWARD: {:10.3f}  | TIME_STEPS: {:5d} | LR: {:3.2e} | EPSILON: {:3.2f} '.format(i_episode, ep_r, time_steps, LR, EPSILON))
            break
        s = s_
# Out:
# Collecting experience...
# EPISODE:  236  |  REWARD:    316.458  | TIME_STEPS:  2235 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  244  |  REWARD:   1608.830  | TIME_STEPS:  3397 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  251  |  REWARD:   1110.614  | TIME_STEPS:  2734 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  258  |  REWARD:    833.146  | TIME_STEPS:  2145 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  263  |  REWARD:    513.659  | TIME_STEPS:  2351 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  264  |  REWARD:   1182.559  | TIME_STEPS:  3008 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  265  |  REWARD:    343.574  | TIME_STEPS:  2298 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  266  |  REWARD:   1059.977  | TIME_STEPS:  2414 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  284  |  REWARD:   1669.131  | TIME_STEPS:  3814 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  290  |  REWARD:    695.852  | TIME_STEPS:  2053 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  291  |  REWARD:   1161.687  | TIME_STEPS:  3702 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  316  |  REWARD:   1057.126  | TIME_STEPS:  2080 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  322  |  REWARD:    992.862  | TIME_STEPS:  2774 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  329  |  REWARD:    967.232  | TIME_STEPS:  2690 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  332  |  REWARD:   1504.609  | TIME_STEPS:  2948 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  342  |  REWARD:    917.371  | TIME_STEPS:  2154 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  346  |  REWARD:   1105.328  | TIME_STEPS:  2522 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  348  |  REWARD:    699.642  | TIME_STEPS:  2662 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  352  |  REWARD:   1116.398  | TIME_STEPS:  2004 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  357  |  REWARD:    644.214  | TIME_STEPS:  2343 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  360  |  REWARD:    960.763  | TIME_STEPS:  3571 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  364  |  REWARD:    802.648  | TIME_STEPS:  2990 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  367  |  REWARD:    445.530  | TIME_STEPS:  2336 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  369  |  REWARD:   1490.827  | TIME_STEPS:  3079 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  377  |  REWARD:   1248.166  | TIME_STEPS:  3666 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  384  |  REWARD:   1299.172  | TIME_STEPS:  2873 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  386  |  REWARD:   1837.930  | TIME_STEPS:  4104 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  387  |  REWARD:    616.915  | TIME_STEPS:  2060 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  395  |  REWARD:    986.637  | TIME_STEPS:  2420 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  397  |  REWARD:   1164.887  | TIME_STEPS:  2652 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  400  |  REWARD:    814.640  | TIME_STEPS:  2421 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  401  |  REWARD:    937.865  | TIME_STEPS:  2430 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  405  |  REWARD:    933.330  | TIME_STEPS:  2673 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  410  |  REWARD:    975.812  | TIME_STEPS:  3581 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  412  |  REWARD:    523.840  | TIME_STEPS:  2377 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  418  |  REWARD:   1086.091  | TIME_STEPS:  2160 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  426  |  REWARD:   1041.892  | TIME_STEPS:  2321 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  444  |  REWARD:   1247.482  | TIME_STEPS:  4974 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  452  |  REWARD:   1015.463  | TIME_STEPS:  2697 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  453  |  REWARD:   1085.053  | TIME_STEPS:  3364 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  464  |  REWARD:    995.788  | TIME_STEPS:  2030 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  470  |  REWARD:    787.188  | TIME_STEPS:  2241 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  475  |  REWARD:   1566.606  | TIME_STEPS:  2748 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  476  |  REWARD:    832.264  | TIME_STEPS:  2301 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  511  |  REWARD:   1059.398  | TIME_STEPS:  2161 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  514  |  REWARD:    626.367  | TIME_STEPS:  2604 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  515  |  REWARD:    471.640  | TIME_STEPS:  2441 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  519  |  REWARD:    809.683  | TIME_STEPS:  2047 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  525  |  REWARD:    650.894  | TIME_STEPS:  2282 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  527  |  REWARD:    580.828  | TIME_STEPS:  2257 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  537  |  REWARD:   1409.124  | TIME_STEPS:  2790 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  539  |  REWARD:   1368.585  | TIME_STEPS:  2792 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  544  |  REWARD:     16.166  | TIME_STEPS:  2566 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  549  |  REWARD:    979.962  | TIME_STEPS:  2073 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  565  |  REWARD:    176.155  | TIME_STEPS:  2302 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  587  |  REWARD:    721.731  | TIME_STEPS:  2851 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  602  |  REWARD:    835.070  | TIME_STEPS:  3069 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  610  |  REWARD:    376.055  | TIME_STEPS:  2225 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  611  |  REWARD:   1114.918  | TIME_STEPS:  3376 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  614  |  REWARD:   1145.776  | TIME_STEPS:  2349 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  633  |  REWARD:    294.576  | TIME_STEPS:  2486 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  663  |  REWARD:    951.665  | TIME_STEPS:  2032 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  673  |  REWARD:   1132.227  | TIME_STEPS:  2208 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  690  |  REWARD:    728.931  | TIME_STEPS:  2025 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  693  |  REWARD:    524.326  | TIME_STEPS:  2793 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  699  |  REWARD:    735.075  | TIME_STEPS:  3041 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  711  |  REWARD:    856.452  | TIME_STEPS:  2556 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  714  |  REWARD:    993.176  | TIME_STEPS:  4041 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  717  |  REWARD:    640.749  | TIME_STEPS:  2467 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  728  |  REWARD:   1039.159  | TIME_STEPS:  2258 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  729  |  REWARD:   1128.316  | TIME_STEPS:  2469 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  730  |  REWARD:    400.464  | TIME_STEPS:  2108 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  731  |  REWARD:   1107.760  | TIME_STEPS:  2375 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  737  |  REWARD:   1232.364  | TIME_STEPS:  3168 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  738  |  REWARD:    951.403  | TIME_STEPS:  2189 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  740  |  REWARD:    723.483  | TIME_STEPS:  2033 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  741  |  REWARD:    936.751  | TIME_STEPS:  2060 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  749  |  REWARD:   1002.207  | TIME_STEPS:  3444 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  753  |  REWARD:    716.710  | TIME_STEPS:  2030 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  754  |  REWARD:    991.923  | TIME_STEPS:  2057 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  755  |  REWARD:   1013.636  | TIME_STEPS:  3954 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  758  |  REWARD:   1043.541  | TIME_STEPS:  2468 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  761  |  REWARD:   2269.655  | TIME_STEPS:  5445 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  787  |  REWARD:    297.218  | TIME_STEPS:  2609 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  791  |  REWARD:   1197.922  | TIME_STEPS:  2762 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  792  |  REWARD:   1055.573  | TIME_STEPS:  3849 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  796  |  REWARD:   1003.559  | TIME_STEPS:  2516 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  798  |  REWARD:    498.721  | TIME_STEPS:  2283 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  800  |  REWARD:   1260.950  | TIME_STEPS:  4799 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  808  |  REWARD:   1368.307  | TIME_STEPS:  2646 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  809  |  REWARD:    955.860  | TIME_STEPS:  2065 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  811  |  REWARD:    567.958  | TIME_STEPS:  3141 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  821  |  REWARD:    903.738  | TIME_STEPS:  2542 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  824  |  REWARD:    560.005  | TIME_STEPS:  2658 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  832  |  REWARD:    846.743  | TIME_STEPS:  2186 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  836  |  REWARD:    740.825  | TIME_STEPS:  3406 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  840  |  REWARD:   1128.684  | TIME_STEPS:  2254 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  841  |  REWARD:   1365.550  | TIME_STEPS:  3266 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  844  |  REWARD:    876.062  | TIME_STEPS:  3969 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  854  |  REWARD:   1532.303  | TIME_STEPS:  3061 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  859  |  REWARD:    621.793  | TIME_STEPS:  2256 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  862  |  REWARD:   1671.419  | TIME_STEPS:  5745 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  879  |  REWARD:    954.129  | TIME_STEPS:  2383 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  880  |  REWARD:   1160.279  | TIME_STEPS:  2406 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  891  |  REWARD:    996.858  | TIME_STEPS:  2344 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  892  |  REWARD:   1078.273  | TIME_STEPS:  2622 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  895  |  REWARD:    800.454  | TIME_STEPS:  3048 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  902  |  REWARD:   1161.969  | TIME_STEPS:  2774 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  908  |  REWARD:    835.242  | TIME_STEPS:  3374 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  912  |  REWARD:    790.644  | TIME_STEPS:  3041 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  918  |  REWARD:    765.147  | TIME_STEPS:  2156 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  919  |  REWARD:    828.419  | TIME_STEPS:  2472 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  931  |  REWARD:    842.531  | TIME_STEPS:  2298 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  933  |  REWARD:   3240.242  | TIME_STEPS:  6155 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  950  |  REWARD:    721.093  | TIME_STEPS:  3280 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  951  |  REWARD:   1246.607  | TIME_STEPS:  2539 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  957  |  REWARD:   1647.925  | TIME_STEPS:  4544 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  961  |  REWARD:   1038.448  | TIME_STEPS:  2227 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  966  |  REWARD:   1096.712  | TIME_STEPS:  2328 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  967  |  REWARD:    928.413  | TIME_STEPS:  3262 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  981  |  REWARD:    353.533  | TIME_STEPS:  2154 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  984  |  REWARD:   1022.932  | TIME_STEPS:  2053 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  986  |  REWARD:    993.739  | TIME_STEPS:  3214 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  988  |  REWARD:    812.438  | TIME_STEPS:  3036 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  990  |  REWARD:    795.699  | TIME_STEPS:  2156 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  991  |  REWARD:   1060.848  | TIME_STEPS:  3371 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  997  |  REWARD:   1949.745  | TIME_STEPS:  4712 | LR: 1.00e-02 | EPSILON: 0.90

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(ep_r_rec,color = 'r');
ax1.set_title('Reward', color = 'r')
ax1.set_yscale('log')

ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(time_rec, color = 'g')
ax2.set_title('Time Steps',color = 'g')
ax2.set_yscale('log')

fig.tight_layout()
plt.show()

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()
